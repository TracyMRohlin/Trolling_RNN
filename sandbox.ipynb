# %% [markdown]
# # Training a neural net to classify personal attacks in Wikipedia comments

# %%
import keras
import os
import pandas as pd
import urllib


from keras.layers.core import Dense, Activation, Flatten
from keras.layers.embeddings import Embedding
from keras.models import Sequential
from keras.preprocessing.text import Tokenizer

# %% [markdown]
# ## Load and pre-process the data.
# ### This is the exact preprocessing method used by Wulczyn, et al, the curators of the data.

# %%
# Download annotated comments and annotations. 
# If you're Tracy, Courtney, or Amandalynne, don't run this step 
# because you already have the data! If you aren't us, you will 
# probably need to do this step. 
# It will take a while. 
ANNOTATED_COMMENTS_URL = 'https://ndownloader.figshare.com/files/7038044' 
ANNOTATIONS_URL = 'https://ndownloader.figshare.com/files/7383751' 


def download_file(url, fname):
    urllib.request.urlretrieve(url, fname)

                
download_file(ANNOTATED_COMMENTS_URL, 'attack_annotated_comments.tsv')
download_file(ANNOTATIONS_URL, 'attack_annotations.tsv')

# %%
# Read the data into a Pandas dataframe.
comments = pd.read_csv('attack_annotated_comments.tsv', sep = '\t', index_col = 0)
annotations = pd.read_csv('attack_annotations.tsv',  sep = '\t')

# Label a comment as an attack if over half of annotators did so.
# We can tinker with this threshold later.
labels = annotations.groupby('rev_id')['attack'].mean() > 0.5

# Join labels and comments
comments['attack'] = labels

# Preprocess the data -- remove newlines, tabs, quotes
# Something to consider: remove Wikipedia style markup (::'s and =='s)
comments['comment'] = comments['comment'].apply(lambda x: x.replace("NEWLINE_TOKEN", " "))
comments['comment'] = comments['comment'].apply(lambda x: x.replace("TAB_TOKEN", " "))
comments['comment'] = comments['comment'].apply(lambda x: x.replace("`", " "))

# %%
# Take a look at the comments
# Look: they've already split the data into train / dev / test :) 
comments
# Out:
#                                                      comment  year logged_in  \
# rev_id
# 37675       - This is not   creative  .  Those are the di...  2002     False
# 44816         :: the term   standard model   is itself le...  2002     False
# 49851        True or false, the situation as of March 200...  2002     False
# 89320       Next, maybe you could work on being less cond...  2002      True
# 93890                   This page will need disambiguation.   2002      True
# 102817      -  Important note for all sysops: There is a ...  2002      True
# 103624     I removed the following:  All names of early P...  2002      True
# 111032      :If you ever claimed in a Judaic studies prog...  2002      True
# 120283        My apologies  I'm English, I watch cricket,...  2002      True
# 128532      Someone wrote: More recognizable, perhaps, is...  2002      True
# 133562       :Correct. Full biographical details will put...  2002      True
# 138117        Care should be taken to distinguish when an...  2002      True
# 155243       :If I may butt in  I've spent the last 1/4 h...  2002      True
# 177310        On my  you will find the apology that I owe...  2002      True
# 192579        :<>>  :I fail to see the distinction.  Who ...  2002      True
# 201190                       gets far more tendentious yet.   2002      True
# 208009        As a person who has done some of this activ...  2002      True
# 249432     It's great that we've found a new source of fr...  2001      True
# 252031         :No, I really haven't heard of either one,...  2001      True
# 268558       I'd like the concepts of microevolution and ...  2001      True
# 276906         I agree, the first one is simply wrong, an...  2001      True
# 286174         Yep, that's Twin cities from which this ar...  2002      True
# 290598            That's another relevant empirical quest...  2001      True
# 294124         : This sounds right. Historians speak of t...  2002      True
# 297866         Ummm. The article uses imperial measuremen...  2001      True
# 317177                             See? I was right! ;-)      2002      True
# 336654       :I have checked the licenses, and it is publ...  2002      True
# 344567       Changed Macedonia link to Macedon; ancients ...  2002      True
# 356383         :Incidentally, re naming conventions: the ...  2002      True
# 358984      I removed   from scratch  . In addition to yo...  2002      True
# ...                                                      ...   ...       ...
# 699646005   Don't keep changing my page I made please. Yo...  2016      True
# 699659494  im soory since when is google images not allow...  2016      True
# 699660419  what ever you fuggin fag Question how did you ...  2016      True
# 699661020    == Nice try but no cigar........idiot ==  Th...  2016      True
# 699661834     == kys ==  {| style=  background-color: #fd...  2016      True
# 699663770    == hi Drmies ==  My name's Little Cletus, I'...  2016      True
# 699664687   shut up mind your own business and go fuck so...  2016      True
# 699667660  This talk page is actually a better place to d...  2016      True
# 699683891    == defunct?== The article sources a claim th...  2016      True
# 699698850    Yeah, I realized I created a duplicate ID. S...  2016      True
# 699702006   :There's some weaseling and pov pushing in th...  2016      True
# 699703322    :::Yeah and in the earlier sentence I'd rewo...  2016      True
# 699715740    :::::::::::::Again, WP:NOTAFORUM (and there'...  2016      True
# 699728036                         [  Those Were the Days  ]   2016      True
# 699730832    == Japanese Scene ==  The largely neoclassic...  2016     False
# 699732149   I am sorry I was only apologizing for if my i...  2016      True
# 699741197     == Jim1138 ==  Hi.  How did you get involve...  2016      True
# 699753082    == Why oh why... ==   You removed the trolls...  2016      True
# 699755057    == Daily Beast Article ==  I'm removing the ...  2016      True
# 699756053   The lead also lacks proper citation and sourc...  2016      True
# 699756185      The lead itself is original research. Wher...  2016      True
# 699780538                       :::::: Well done, thanks!     2016     False
# 699813325    ::I'm talking about you making unjustified m...  2016      True
# 699820699    Yes, from the word   Guci   or   Puci   mean...  2016      True
# 699822249     :  Comment    . Gentlemen, this article pro...  2016      True
# 699848324      These sources don't exactly exude a sense ...  2016      True
# 699851288    The Institute for Historical Review is a pee...  2016      True
# 699857133   :The way you're trying to describe it in this...  2016      True
# 699891012    == Warning ==  There is clearly a protection...  2016      True
# 699897151  Alternate option=== Is there perhaps enough ne...  2016      True
#
#                 ns   sample  split attack
# rev_id
# 37675      article   random  train  False
# 44816      article   random  train  False
# 49851      article   random  train  False
# 89320      article   random    dev  False
# 93890      article   random  train  False
# 102817        user   random  train  False
# 103624     article   random  train  False
# 111032     article   random    dev  False
# 120283     article   random    dev  False
# 128532     article   random  train  False
# 133562     article   random  train  False
# 138117     article   random  train  False
# 155243        user   random   test  False
# 177310        user   random   test  False
# 192579     article   random  train  False
# 201190     article   random    dev  False
# 208009        user   random  train  False
# 249432     article   random  train  False
# 252031     article   random  train  False
# 268558     article   random  train  False
# 276906     article   random  train  False
# 286174     article   random   test  False
# 290598     article   random    dev  False
# 294124     article   random  train  False
# 297866     article   random  train  False
# 317177     article   random   test  False
# 336654        user   random    dev  False
# 344567     article   random  train  False
# 356383     article   random  train  False
# 358984     article   random    dev  False
# ...            ...      ...    ...    ...
# 699646005     user  blocked  train  False
# 699659494     user  blocked    dev   True
# 699660419     user  blocked   test   True
# 699661020     user  blocked  train   True
# 699661834     user  blocked   test  False
# 699663770     user  blocked  train  False
# 699664687     user  blocked    dev   True
# 699667660  article  blocked  train  False
# 699683891  article  blocked  train  False
# 699698850     user  blocked   test  False
# 699702006  article  blocked  train  False
# 699703322  article  blocked   test  False
# 699715740  article  blocked    dev  False
# 699728036  article   random  train  False
# 699730832  article  blocked    dev  False
# 699732149     user   random  train  False
# 699741197     user  blocked    dev  False
# 699753082     user  blocked   test  False
# 699755057  article  blocked    dev  False
# 699756053  article  blocked    dev  False
# 699756185  article  blocked  train  False
# 699780538     user  blocked    dev  False
# 699813325  article  blocked  train  False
# 699820699     user  blocked    dev  False
# 699822249  article  blocked    dev  False
# 699848324  article  blocked  train  False
# 699851288  article  blocked   test  False
# 699857133  article  blocked  train  False
# 699891012     user  blocked    dev  False
# 699897151  article  blocked  train  False
#
# [115864 rows x 7 columns]

# %%
# Grab the training data (seems to be 60%)
train_data = comments.loc[comments['split'] == 'train']

# %%
train_data
# Out:
#                                                      comment  year logged_in  \
# rev_id
# 37675       - This is not   creative  .  Those are the di...  2002     False
# 44816         :: the term   standard model   is itself le...  2002     False
# 49851        True or false, the situation as of March 200...  2002     False
# 93890                   This page will need disambiguation.   2002      True
# 102817      -  Important note for all sysops: There is a ...  2002      True
# 103624     I removed the following:  All names of early P...  2002      True
# 128532      Someone wrote: More recognizable, perhaps, is...  2002      True
# 133562       :Correct. Full biographical details will put...  2002      True
# 138117        Care should be taken to distinguish when an...  2002      True
# 192579        :<>>  :I fail to see the distinction.  Who ...  2002      True
# 208009        As a person who has done some of this activ...  2002      True
# 249432     It's great that we've found a new source of fr...  2001      True
# 252031         :No, I really haven't heard of either one,...  2001      True
# 268558       I'd like the concepts of microevolution and ...  2001      True
# 276906         I agree, the first one is simply wrong, an...  2001      True
# 294124         : This sounds right. Historians speak of t...  2002      True
# 297866         Ummm. The article uses imperial measuremen...  2001      True
# 344567       Changed Macedonia link to Macedon; ancients ...  2002      True
# 356383         :Incidentally, re naming conventions: the ...  2002      True
# 360594       ::I disagree. I would leave it out of the in...  2002     False
# 377054       :::I don't know where you got the idea that ...  2002     False
# 388807       Ezra, you have got to be kidding with this p...  2002      True
# 398923        ::::: There's nothing particularly objectio...  2002      True
# 460946       :::Yet more:  Follow the whole thread if you...  2002      True
# 537948       Hi Alex  Just thought I ought to mention tha...  2002      True
# 546902        Early Imperial, Mid-Imperial and Late Imper...  2002      True
# 554005         The references to the Congolese economy se...  2003      True
# 569192         I cut the following paragraph, which misle...  2003      True
# 583986       Dear Mav: Thanks, bro! God bless you!  Since...  2003      True
# 586452     On Google Vereenigde Oost-Indische Compagnie g...  2002      True
# ...                                                      ...   ...       ...
# 699490271                   I LOVE VIENNESE OYSTERS!!!!       2016     False
# 699522986     == Dogs ==  One question, how many dogs do ...  2016      True
# 699528880   Kosovo   Zoupan, dont delete my texts just be...  2016      True
# 699549435     Motherfucka the whole   Blanqueamento in Pu...  2016      True
# 699563903    :: Oh, I thought you were an Indian Pariah D...  2016      True
# 699565779    == The Rams are now gone from Skank Louis.  ...  2016      True
# 699578052      == Question ==  How do you add references?     2016      True
# 699596750   ::@ we have been over the prophethood bit lon...  2016      True
# 699598266    ::::@ so you have no sources that state that...  2016      True
# 699598285     == Inadequacy of the page == At best, creat...  2016     False
# 699599490   ::::::@ 16 sources say he was not, while THIR...  2016      True
# 699603533     ==  The Returds Need to GET A LIFE!!!  == I...  2016     False
# 699604332   GET A LIFE DHASS HOLE!==  Finding articles 10...  2016     False
# 699606829   | date2 = 21 December 2015 | result2 = no con...  2016      True
# 699621440   :True, put them in as well. I just torrented ...  2016      True
# 699642939  , you people want me to debase myself at the h...  2016      True
# 699645524   Brandon Semenuk has won the event four times ...  2016      True
# 699646005   Don't keep changing my page I made please. Yo...  2016      True
# 699661020    == Nice try but no cigar........idiot ==  Th...  2016      True
# 699663770    == hi Drmies ==  My name's Little Cletus, I'...  2016      True
# 699667660  This talk page is actually a better place to d...  2016      True
# 699683891    == defunct?== The article sources a claim th...  2016      True
# 699702006   :There's some weaseling and pov pushing in th...  2016      True
# 699728036                         [  Those Were the Days  ]   2016      True
# 699732149   I am sorry I was only apologizing for if my i...  2016      True
# 699756185      The lead itself is original research. Wher...  2016      True
# 699813325    ::I'm talking about you making unjustified m...  2016      True
# 699848324      These sources don't exactly exude a sense ...  2016      True
# 699857133   :The way you're trying to describe it in this...  2016      True
# 699897151  Alternate option=== Is there perhaps enough ne...  2016      True
#
#                 ns   sample  split attack
# rev_id
# 37675      article   random  train  False
# 44816      article   random  train  False
# 49851      article   random  train  False
# 93890      article   random  train  False
# 102817        user   random  train  False
# 103624     article   random  train  False
# 128532     article   random  train  False
# 133562     article   random  train  False
# 138117     article   random  train  False
# 192579     article   random  train  False
# 208009        user   random  train  False
# 249432     article   random  train  False
# 252031     article   random  train  False
# 268558     article   random  train  False
# 276906     article   random  train  False
# 294124     article   random  train  False
# 297866     article   random  train  False
# 344567     article   random  train  False
# 356383     article   random  train  False
# 360594        user  blocked  train  False
# 377054        user  blocked  train  False
# 388807     article   random  train  False
# 398923     article   random  train  False
# 460946     article   random  train  False
# 537948        user   random  train  False
# 546902     article   random  train  False
# 554005        user   random  train  False
# 569192     article   random  train  False
# 583986        user   random  train  False
# 586452     article   random  train  False
# ...            ...      ...    ...    ...
# 699490271     user  blocked  train  False
# 699522986     user  blocked  train  False
# 699528880  article  blocked  train  False
# 699549435     user  blocked  train   True
# 699563903     user  blocked  train  False
# 699565779     user  blocked  train  False
# 699578052     user  blocked  train  False
# 699596750  article  blocked  train  False
# 699598266  article  blocked  train  False
# 699598285  article   random  train  False
# 699599490  article  blocked  train  False
# 699603533  article  blocked  train  False
# 699604332     user  blocked  train   True
# 699606829  article   random  train  False
# 699621440  article  blocked  train  False
# 699642939     user  blocked  train  False
# 699645524     user  blocked  train   True
# 699646005     user  blocked  train  False
# 699661020     user  blocked  train   True
# 699663770     user  blocked  train  False
# 699667660  article  blocked  train  False
# 699683891  article  blocked  train  False
# 699702006  article  blocked  train  False
# 699728036  article   random  train  False
# 699732149     user   random  train  False
# 699756185  article  blocked  train  False
# 699813325  article  blocked  train  False
# 699848324  article  blocked  train  False
# 699857133  article  blocked  train  False
# 699897151  article  blocked  train  False
#
# [69526 rows x 7 columns]

# %%
# Put all the training data (comments) into a list
train_texts = train_data["comment"].tolist()

# %%
# If you want to see a snippet of it for a sanity check:
train_text[:10]
# Out:
# [" - This is not   creative  .  Those are the dictionary definitions of the terms   insurance   and   ensurance   as properly applied to   destruction  .  If you don't understand that, fine, legitimate criticism, I'll write up   three man cell   and   bounty hunter   and then it will be easy to understand why   ensured   and   insured   are different - and why both differ from   assured  .  The sentence you quote is absolutely neutral.  You just aren't familiar with the underlying theory of strike-back (e.g. submarines as employed in nuclear warfare) guiding the insurance, nor likely the three man cell structure that kept the IRA from being broken by the British.  If that's my fault, fine, I can fix that to explain.  But ther'es nothing   personal   or   creative   about it.  I'm tired of arguing with you.  Re: the other article,   multi-party   turns up plenty, and there is more use of   mutually   than   mutual  .  If I were to apply your standard I'd be moving   Mutual Assured Destruction   to   talk   for not appealing to a Reagan voter's biases about its effectiveness, and for dropping the   ly  .  There is a double standard in your edits.  If it comes from some US history book, like   peace movement   or 'M.A.D.' as defined in 1950, you like it, even if the definition is totally useless in 2002 and only of historical interest.    If it makes any even-obvious connection or implication from the language chosen in multiple profession-specific terms, you consider it somehow non-neutral...  Gandhi thinks   eye for an eye   describes riots, death penalty, and war all at once, but you don't.  What do you know that Gandhi doesn't?  Guess what:  reality is not neutral.  Current use of terms is slightly more controversial.  Neutrality requires negotiation, and some willingness to learn.  This is your problem not mine.  You may dislike the writing, fine, that can be fixed.  But disregarding fundamental axioms of philosphy with names that recur in multiple phrases, or failing to make critical distinctions like 'insurance' versus 'assurance' versus 'ensurance' (which are made in one quote by an Air Force general in an in-context quote), is just a disservice to the reader.  If someone comes here to research a topic like MAD, they want some context, beyond history.  If this is a history book, fine, it's a history book.  But that wasn't what it was claimed to be...  ",
#  "   :: the term   standard model   is itself less NPOV than I think we'd prefer...  :: if it's   new-age speak   then a lot of old-age people speak it - Karl Popper, the Pope, etc.  here's Karl Popper's view of this.  :: The clearest title for this article would be   particle physics cosmology   - but as I say that would require broader treatment of issues like the Anthropic Principle, cognitive bias beyond the particle physics zoo, etc.  :: as to accelerators, it's clear that while they are in use, someone is still looking for particles.  So this is not yet a settled   cosmology   so certain that we abandon the search... nor is it an arbitrary foundation ontology as you suggest, not subject to question. ",
#  "  True or false, the situation as of March 2002 was such:  A Saudi proposal of Land for Peace AND recognition by ALL arab countries was made. The day the proposal was to be made formal by the Arab League was the day the Israeli's under the command of Ariel Sharon began the invasion of the Palestinian self-rule areas. user:Arab.",
#  'This page will need disambiguation. ',
#  ' -  Important note for all sysops: There is a bug in the administrative move feature that truncates the moved history and changes the edit times.  Please do not use this feature until this bug is fixed. More information can be found in the talk of  and . Thank you. ',
#  'I removed the following:  All names of early Polish rulers are ficticious and therefore this index naming Oda von Haldensleben and her husband Dagome records for the first time rulers of the Polanen tribe. Therefore it is indicated as being the first document of the later developing land named Poland.  This is quite a comment. All names are fictitious? It deserves at least some backing. ',
#  " Someone wrote: More recognizable, perhaps, is a type of what is generally called rock and roll called [folk rock]? or simply   folk,   which included performers such as [Joan Baez]?, Bob Dylan, Simon and Garfunkel, [The Mamas and the Papas]?, and many others.   I've tried to clarify this.   Folk rock   is used very specifically and is typically far more recognised by instrumentation than form. Many folk musicians of the 60s (Tom Paxton, Phil Ochs etc) sang new, topical material (which distinguished them from traditional folk musicians) but in the folk idiom (acoustic instruments, traditional arrangements and often traditional melodies.)  Re: the comment about   marketers   in the first paragraph. If language reflects common usage, what is now called   folk music   has as much right to the name as any other form. Gareth Owen  To the latter: fair enough, but does the first paragraph actually imply otherwise? LMS  I like the page in general but wonder if the following is unnecessarily cynical (implying, as it does, a financial rather than artistic incentive to change musical styles): :  Some of these performers, of which Joan Baez is an excellent example, began their commercial music careers performing traditional music in a traditional idiom, but soon transformed their style and accompaniment to suit popular tastes.    Ya know, I agree, but I don't know how to change it right off. Anyone else want to give it a stab? LMS  The deletions are merely of things that seemed redundant. Additions may solve the problem of tone mentioned above. One bit of the original puzzles me, so I corrected the grammar but left it inbut what does   unrecognizable to its source   actually mean?  I like the new additionslots of good new information here. I added some more. The problem now is that the article is rambling and disorganized, and I am probably not the best person to organize and clarify it. BTW, using the word   purist,   without the quotes, makes it sound as if the authors of the article are not purists, which we don't want to imply. -) See neutral point of view. LMS  Perhaps someone who knows the facts -) could add in   Skiffle   music, from whence the Beatles sprang, which was evidently a British folk form in the 1950's.  Certainly the Beatles stole (er, utilised!) many folk forms in their music.  ",
#  "  :Correct. Full biographical details will put down his birth details, etc. It is just a marker to me at the moment to detail the WR aspect. He certainly wasn't Belarus; as a geo-political entity it had no real existence at the time. I have put a tbc marker on this article for now. ",
#  '   Care should be taken to distinguish when and if definitions of   express   and   special delivery   stamps are written that while in many countries the definition is the same in the United States there is a definite difference between   Express Mail   and the (now defunct)   Special Delivery.    ',
#  '   :<>>  :I fail to see the distinction.  Who better than legal scholars to define what the law is?  Moreover, my comments in re how legal scholars define the law were a response to your dubious assertion that law qua law can be defined as a   decision process.    That assertion has no place in the main law article.  :<>  :I disagree.  The enactment of a statute falls under the topic of legislation.  :<>  :These issues are not law qua law; they are topics which should be discussed under the ambit of particular legal topics, such as   statutory interpretation   or   contracts,   or related topics, such as   sociology   and   political science.    :<>  :Law qua law is first and foremost a body of knowledge:  The academic field to which you refer is the study of that body of knowledge, and should be considered as part and parcel of the discussion found in the main law article; the profession of law is the application of that body of knowledge, which should be discussed in the   practice of law   article. ']

# %%
len(train_text)
# Out:
# 69526

# %%
# A set of character unigrams.
# This number may come in handy later
char_unigrams = set(train_text)

# Note: there are 728 unique characters.

# %%
# This function makes the char ngrams we want. 
# Default to 1-5, as in the paper
def char_ngram_generator(text, n1=1, n2=5):
    z = []
    text2 = '*'+text+'*'
    for k in range(n1,n2):
        z.append([text2[i:i+k] for i in range(len(text2)-k+1)])
    z = [ngram for ngrams in z for ngram in ngrams]
    z.append(text)
    return set(z)

# %% [markdown]
# # Fiddling around with keras Tokenizer to make the character embeddings. Work in progress.

# %%
# The char-level tokenizer will only produce character unigrams.
# Figuring out the 2..5 grams will come another day.
# We may want to set a threshold for frequency, e.g. only care about
# top 100 most frequent chars / char sequences. 
tokenizer = keras.preprocessing.text.Tokenizer(char_level=True)

# %%
# Fit it to the training data.
tokenizer.fit_on_texts(train_texts)

# %%
# Take a look at the character counts for fun
tokenizer.word_counts
# Out:
# {' ': 5351570,
#  '-': 51321,
#  'T': 113251,
#  'h': 943891,
#  'i': 1572357,
#  's': 1326059,
#  'n': 1417949,
#  'o': 1659847,
#  't': 1889196,
#  'c': 612939,
#  'r': 1188214,
#  'e': 2486567,
#  'a': 1696248,
#  'v': 214828,
#  '.': 294108,
#  'd': 764831,
#  'y': 454043,
#  'f': 392185,
#  'm': 487940,
#  'u': 657833,
#  'p': 426631,
#  'l': 856363,
#  'I': 189734,
#  "'": 98998,
#  ',': 209650,
#  'g': 427725,
#  'w': 341809,
#  'b': 310011,
#  'q': 19512,
#  'Y': 40097,
#  'j': 31726,
#  'k': 223359,
#  '(': 31615,
#  ')': 34335,
#  'R': 55088,
#  'A': 114695,
#  'B': 42454,
#  'x': 39931,
#  ':': 105879,
#  'M': 48770,
#  'D': 44483,
#  'U': 48932,
#  'S': 88004,
#  '1': 35413,
#  '9': 15515,
#  '5': 12718,
#  '0': 41861,
#  '2': 28258,
#  'G': 40618,
#  'W': 67605,
#  '?': 34090,
#  'C': 68171,
#  'N': 63965,
#  'F': 44156,
#  'P': 55064,
#  'O': 71824,
#  'V': 14918,
#  'K': 29262,
#  'z': 19348,
#  'L': 46460,
#  'H': 62782,
#  '[': 3258,
#  ']': 3661,
#  'J': 18911,
#  '6': 10077,
#  '!': 66567,
#  ';': 11675,
#  'E': 76531,
#  '<': 203,
#  '>': 721,
#  '/': 27683,
#  'ö': 139,
#  '4': 11216,
#  '3': 14261,
#  '_': 8163,
#  '’': 2300,
#  '*': 15355,
#  '8': 10478,
#  '+': 1265,
#  '=': 116919,
#  'Q': 2447,
#  '7': 10066,
#  '~': 2595,
#  '%': 2731,
#  'Z': 2315,
#  'X': 1857,
#  'ï': 22,
#  '@': 1151,
#  'ĉ': 2,
#  '#': 4863,
#  '&': 3180,
#  '|': 12808,
#  '地': 1,
#  '方': 2,
#  '自': 6,
#  '治': 2,
#  '法': 2,
#  '{': 2621,
#  '}': 2789,
#  '–': 1247,
#  '—': 2300,
#  '¼': 3,
#  '½': 8,
#  '\xa0': 1702,
#  '´': 248,
#  'ó': 109,
#  '≠': 9,
#  'â': 62,
#  'ê': 13,
#  '█': 3,
#  'ā': 67,
#  'ō': 42,
#  'ß': 20,
#  'Ö': 20,
#  '§': 58,
#  '“': 1381,
#  '”': 1363,
#  '→': 224,
#  'σ': 16,
#  'υ': 11,
#  'ν': 29,
#  'α': 48,
#  'γ': 12,
#  'ω': 15,
#  'ή': 12,
#  'ά': 8,
#  'ε': 32,
#  'ι': 26,
#  '£': 37,
#  '^': 339,
#  'é': 389,
#  'á': 137,
#  'í': 110,
#  'π': 23,
#  'О': 12,
#  'б': 66,
#  'р': 232,
#  'е': 311,
#  'з': 60,
#  'а': 455,
#  'н': 259,
#  'и': 365,
#  '$': 417,
#  '上': 3,
#  '字': 2,
#  '辨': 2,
#  '陰': 1,
#  '陽': 1,
#  '，': 15,
#  '下': 2,
#  '平': 2,
#  '仄': 1,
#  'দ': 1,
#  '•': 2284,
#  'ψ': 5,
#  '虎': 2,
#  '門': 1,
#  'Ä': 5,
#  '\\': 223,
#  'ä': 77,
#  '·': 517,
#  '¹': 8,
#  '道': 6,
#  '家': 7,
#  '教': 1,
#  '張': 2,
#  '陵': 1,
#  '⇝': 2,
#  '…': 154,
#  '庄': 1,
#  '子': 3,
#  '和': 5,
#  '蝴': 1,
#  '蝶': 1,
#  'ú': 20,
#  '顧': 1,
#  '輝': 1,
#  '仙': 2,
#  '度': 2,
#  '拉': 2,
#  '啼': 1,
#  '笑': 2,
#  '姻': 1,
#  '緣': 1,
#  'à': 39,
#  '«': 24,
#  '»': 31,
#  'ù': 10,
#  'î': 25,
#  'è': 44,
#  'æ': 44,
#  '∴': 2,
#  '©': 25,
#  'φ': 5,
#  '≡': 7,
#  '¦': 35,
#  'ı': 170,
#  'ü': 175,
#  '♬': 4,
#  '‘': 352,
#  'М': 18,
#  'Л': 5,
#  'Д': 16,
#  'В': 23,
#  'И': 12,
#  'Й': 3,
#  'Я': 5,
#  'З': 6,
#  'Б': 7,
#  'ă': 53,
#  'Н': 10,
#  'ş': 76,
#  'ţ': 24,
#  '⇔': 10,
#  '१': 1,
#  '२': 1,
#  '३': 1,
#  '४': 1,
#  '५': 1,
#  '६': 1,
#  '७': 1,
#  '८': 1,
#  '९': 1,
#  '唐': 2,
#  '手': 2,
#  'Β': 2,
#  'ο': 47,
#  'ς': 24,
#  'τ': 12,
#  'ῶ': 2,
#  'ρ': 21,
#  'ὶ': 1,
#  'ῆ': 2,
#  'ἑ': 1,
#  'λ': 26,
#  'η': 12,
#  'κ': 23,
#  'ᾶ': 1,
#  'Ἐ': 1,
#  'μ': 19,
#  'ἀ': 1,
#  'δ': 12,
#  'ί': 14,
#  'ξ': 4,
#  'Ð': 2,
#  'ð': 12,
#  'đ': 27,
#  'Đ': 12,
#  '⇒': 12,
#  '✉': 19,
#  'Ε': 15,
#  'Ρ': 3,
#  'ϊ': 1,
#  'ό': 7,
#  'ώ': 4,
#  'ē': 8,
#  'Λ': 4,
#  'Η': 3,
#  'Ν': 4,
#  'Ι': 3,
#  'Κ': 6,
#  'Α': 3,
#  'χ': 4,
#  '←': 52,
#  '°': 41,
#  'Ü': 3,
#  'ź': 2,
#  'ż': 26,
#  'Š': 25,
#  'å': 25,
#  'Ì': 4,
#  'ɥ': 2,
#  'Á': 8,
#  'š': 74,
#  'É': 33,
#  'ダ': 1,
#  'チ': 3,
#  'ョ': 4,
#  'ウ': 9,
#  '倶': 1,
#  '楽': 1,
#  '部': 4,
#  '所': 1,
#  'ジ': 3,
#  'ー': 5,
#  '×': 4,
#  '内': 1,
#  '外': 1,
#  '¢': 4,
#  'ا': 167,
#  'ل': 153,
#  'س': 35,
#  'م': 88,
#  'ع': 42,
#  'ي': 90,
#  'ك': 24,
#  '松': 6,
#  '涛': 6,
#  '濤': 2,
#  '小': 5,
#  '刀': 5,
#  '÷': 5,
#  'ć': 111,
#  'Å': 7,
#  '➨': 2,
#  '¿': 9,
#  '˜': 8,
#  'Č': 13,
#  'ě': 8,
#  'ý': 7,
#  'č': 45,
#  'ž': 23,
#  'ř': 4,
#  'か': 1,
#  'し': 8,
#  'ま': 5,
#  '～': 2,
#  'ガ': 10,
#  'ル': 2,
#  '・': 11,
#  'ミ': 1,
#  'ツ': 4,
#  'ő': 4,
#  '√': 2,
#  'ʑ': 3,
#  'ɾ': 2,
#  'ਸ': 13,
#  'ੁ': 5,
#  'ਖ': 5,
#  'ł': 37,
#  'ø': 28,
#  'ホ': 2,
#  'ロ': 4,
#  '科': 1,
#  'Ц': 4,
#  'с': 235,
#  'к': 198,
#  'о': 397,
#  'в': 168,
#  'ы': 43,
#  'ç': 107,
#  'ī': 20,
#  'ṇ': 4,
#  'ś': 11,
#  'ū': 29,
#  'ʃ': 3,
#  'ğ': 32,
#  'ˉ': 6,
#  '╞': 1,
#  '╡': 1,
#  'ˑ': 2,
#  '¨': 19,
#  '™': 24,
#  'מ': 9,
#  'ו': 23,
#  'ז': 6,
#  'י': 19,
#  'א': 13,
#  'ן': 3,
#  'ש': 17,
#  'ר': 21,
#  'ל': 13,
#  'ה': 20,
#  'כ': 6,
#  'ס': 2,
#  'פ': 3,
#  '≈': 13,
#  'ë': 17,
#  'Δ': 5,
#  'Ξ': 2,
#  'Ω': 2,
#  'Σ': 8,
#  'Υ': 2,
#  'Τ': 4,
#  'д': 126,
#  'ј': 19,
#  'Μ': 4,
#  'ò': 8,
#  'ồ': 3,
#  'あ': 2,
#  'ず': 1,
#  'み': 1,
#  '椋': 1,
#  '\x95': 3,
#  '²': 9,
#  '永': 1,
#  '訣': 1,
#  'Î': 4,
#  '♥': 35,
#  'Ч': 4,
#  'м': 109,
#  'ц': 30,
#  'ь': 52,
#  'נ': 9,
#  'ĩ': 4,
#  '\x97': 3,
#  '‧': 4,
#  '\u2002': 6,
#  'ə': 32,
#  'ˈ': 17,
#  'ɜ': 3,
#  'ɪ': 14,
#  'ח': 7,
#  'ט': 2,
#  'Χ': 2,
#  'İ': 18,
#  'õ': 17,
#  'ג': 5,
#  'ם': 4,
#  'ת': 14,
#  'म': 18,
#  'ह': 16,
#  'ा': 69,
#  'र': 25,
#  'ष': 3,
#  '्': 17,
#  'ट': 10,
#  'ư': 5,
#  'ờ': 4,
#  'ơ': 2,
#  '☯': 12,
#  'ô': 18,
#  'г': 68,
#  '\x93': 12,
#  '\x94': 12,
#  'Ќ': 2,
#  '╫': 4,
#  'ע': 7,
#  'و': 84,
#  'ر': 66,
#  'ج': 26,
#  'ñ': 23,
#  '►': 44,
#  '♪': 17,
#  '♫': 24,
#  '\u200e': 350,
#  'Π': 6,
#  'ζ': 5,
#  '球': 2,
#  '♦': 37,
#  '六': 1,
#  '月': 2,
#  '二': 1,
#  '日': 3,
#  '¡': 7,
#  '✍': 1,
#  '„': 13,
#  'Ś': 7,
#  'ą': 3,
#  'ę': 11,
#  'ã': 52,
#  'Ó': 8,
#  '♣': 35,
#  '�': 7,
#  '正': 1,
#  '步': 1,
#  '♠': 11,
#  '\u3000': 5,
#  'х': 20,
#  'л': 149,
#  'й': 62,
#  'т': 223,
#  'ш': 34,
#  'Ψ': 4,
#  'フ': 9,
#  'ァ': 1,
#  'ン': 21,
#  'ソ': 1,
#  'ギ': 1,
#  'Ṣ': 2,
#  'Ǔ': 3,
#  '↔': 3,
#  'È': 4,
#  '声': 2,
#  '援': 2,
#  '大': 8,
#  'Ō': 6,
#  'ن': 56,
#  'θ': 17,
#  'ń': 11,
#  '≤': 1,
#  'β': 12,
#  '±': 37,
#  '†': 18,
#  '⅔': 2,
#  '山': 3,
#  '本': 4,
#  '一': 4,
#  '郎': 3,
#  'у': 77,
#  'п': 110,
#  'ч': 50,
#  'А': 36,
#  'С': 18,
#  'К': 15,
#  'ж': 35,
#  'ќ': 4,
#  'ѓ': 3,
#  'Г': 10,
#  'ф': 11,
#  'љ': 4,
#  'я': 70,
#  'Р': 9,
#  'ё': 7,
#  '⁄': 3,
#  '竜': 3,
#  '龍': 1,
#  '國': 30,
#  '格': 1,
#  '言': 3,
#  '：': 3,
#  '無': 2,
#  'Ḍ': 3,
#  'ै': 4,
#  'त': 17,
#  'ु': 9,
#  'य': 5,
#  'व': 4,
#  'क': 13,
#  'ौ': 1,
#  'न': 36,
#  'ी': 13,
#  'ं': 7,
#  'स': 14,
#  'ब': 11,
#  'ऐ': 1,
#  'द': 10,
#  'ो': 7,
#  'ड': 13,
#  '़': 23,
#  'ल': 17,
#  'छ': 6,
#  'औ': 1,
#  'ॉ': 6,
#  'ऑ': 3,
#  'ि': 7,
#  'च': 3,
#  'ज': 11,
#  'ू': 6,
#  'प': 15,
#  'े': 7,
#  'ख': 10,
#  'ँ': 7,
#  'अ': 2,
#  'ग': 6,
#  'आ': 1,
#  'ॅ': 3,
#  'घ': 1,
#  'थ': 3,
#  'ृ': 2,
#  'ऊ': 1,
#  'ठ': 2,
#  'ध': 1,
#  'फ': 2,
#  'テ': 1,
#  'レ': 1,
#  'ビ': 3,
#  '番': 1,
#  '組': 2,
#  'の': 9,
#  '攻': 1,
#  '撃': 1,
#  '！': 1,
#  'ὼ': 1,
#  'έ': 5,
#  'ǽ': 1,
#  'ǣ': 3,
#  '\uf6fc': 1,
#  '\uf701': 1,
#  'П': 15,
#  'ǎ': 3,
#  'ǔ': 2,
#  'Е': 6,
#  '◄': 1,
#  'º': 9,
#  '®': 18,
#  'ʻ': 2,
#  '∞': 3,
#  '☺': 18,
#  '‹': 4,
#  '›': 4,
#  '\u202f': 1,
#  '\u2060': 12,
#  'ʘ': 3,
#  '说': 1,
#  'Ş': 8,
#  'Ø': 3,
#  '健': 1,
#  '次': 1,
#  '−': 46,
#  '≥': 3,
#  '●': 3,
#  'บ': 1,
#  'ร': 2,
#  'พ': 2,
#  'ต': 1,
#  'ิ': 1,
#  'ส': 1,
#  'ั': 2,
#  'ย': 6,
#  'ự': 6,
#  'ễ': 2,
#  'ố': 4,
#  'ữ': 1,
#  '？': 1,
#  'щ': 7,
#  '☭': 1,
#  '☻': 2,
#  'ش': 23,
#  'د': 35,
#  'أ': 18,
#  '‑': 6,
#  'ד': 3,
#  'ב': 12,
#  '\u2009': 9,
#  '♩': 2,
#  '☆': 3,
#  '\ufeff': 9,
#  '台': 3,
#  '成': 2,
#  '¤': 4,
#  '¬': 7,
#  'ű': 2,
#  '칠': 1,
#  '지': 1,
#  '도': 1,
#  'ŏ': 2,
#  '豆': 3,
#  '田': 3,
#  '原': 4,
#  '真': 4,
#  '人': 7,
#  '出': 5,
#  '謚': 2,
#  '敏': 4,
#  '達': 4,
#  '孫': 3,
#  '百': 8,
#  '済': 7,
#  '王': 8,
#  '也': 3,
#  '史': 2,
#  '乙': 1,
#  '継': 1,
#  '都': 1,
#  '慕': 1,
#  '十': 1,
#  '八': 1,
#  '世': 3,
#  '武': 2,
#  '寧': 1,
#  'う': 4,
#  '犬': 1,
#  '冒': 1,
#  '険': 1,
#  '（': 5,
#  '✰': 2,
#  '湖': 1,
#  '派': 1,
#  '樊': 1,
#  '伯': 2,
#  '炎': 1,
#  'غ': 10,
#  'ب': 50,
#  'ی': 7,
#  'آ': 4,
#  'ذ': 4,
#  '濟': 1,
#  '主': 3,
#  '照': 2,
#  '古': 1,
#  '以': 2,
#  '牡': 1,
#  '馬': 2,
#  '壹': 2,
#  '疋': 2,
#  '牝': 1,
#  '付': 1,
#  '阿': 1,
#  '知': 1,
#  '吉': 1,
#  '師': 2,
#  '貢': 2,
#  '賜': 1,
#  '新': 1,
#  '撰': 1,
#  '姓': 1,
#  '氏': 1,
#  '録': 1,
#  'ἐ': 1,
#  'ḍ': 2,
#  'ẓ': 4,
#  '⅞': 2,
#  'ƒ': 9,
#  'ɑ': 8,
#  '招': 1,
#  '回': 2,
#  '《': 6,
#  '》': 6,
#  '\uf733': 1,
#  '\uf736': 2,
#  '\uf730': 5,
#  '\uf732': 2,
#  '\uf735': 2,
#  '\uf734': 2,
#  '\uf731': 3,
#  '\uf739': 1,
#  '\uf6de': 1,
#  '\uf737': 3,
#  '\uf738': 2,
#  '⁴': 1,
#  '⁰': 2,
#  'ŭ': 5,
#  '⅛': 2,
#  'ˡ': 6,
#  'ʕ': 11,
#  'ⲧ': 2,
#  'ⲟ': 1,
#  'ⲩ': 1,
#  'ⲱ': 1,
#  'ʔ': 4,
#  'Ш': 3,
#  '\xad': 5,
#  'ㄏ': 1,
#  'ㄨ': 1,
#  'ㄤ': 1,
#  'ㄉ': 1,
#  'ㄧ': 1,
#  '☼': 2,
#  'ģ': 3,
#  '很': 3,
#  '佩': 2,
#  '服': 2,
#  '你': 6,
#  '祝': 1,
#  '过': 1,
#  '个': 1,
#  '好': 3,
#  '天': 2,
#  '谢': 4,
#  '。': 13,
#  '‡': 1,
#  '↑': 2,
#  '↓': 1,
#  '¶': 5,
#  '⅓': 1,
#  '¾': 1,
#  '⅜': 1,
#  '⅝': 1,
#  '₳': 1,
#  '฿': 1,
#  '₵': 2,
#  '₡': 1,
#  '₢': 1,
#  '₫': 1,
#  '₯': 1,
#  '€': 9,
#  '₠': 1,
#  '₣': 1,
#  '₴': 1,
#  '₭': 1,
#  '₤': 1,
#  'ℳ': 1,
#  '₥': 1,
#  '₦': 1,
#  '№': 1,
#  '₧': 1,
#  '₰': 1,
#  '៛': 1,
#  '₨': 1,
#  '₪': 5,
#  '৳': 1,
#  '₮': 1,
#  '₩': 1,
#  '¥': 1,
#  '³': 2,
#  'Ć': 1,
#  'Í': 2,
#  'Ĺ': 1,
#  'ĺ': 1,
#  'Ń': 1,
#  'Ŕ': 1,
#  'ŕ': 2,
#  'Ú': 2,
#  'Ý': 1,
#  'Ź': 1,
#  'À': 1,
#  'ì': 6,
#  'Ò': 2,
#  'Ù': 1,
#  'Â': 2,
#  'Ĉ': 1,
#  'Ê': 1,
#  'Ĝ': 1,
#  'ĝ': 1,
#  'Ĥ': 1,
#  'ĥ': 2,
#  'Ĵ': 2,
#  'ĵ': 1,
#  'Ô': 1,
#  'Ŝ': 1,
#  'ŝ': 1,
#  'Û': 1,
#  'û': 1,
#  'Ŵ': 2,
#  'ŵ': 1,
#  'Ŷ': 1,
#  'ŷ': 1,
#  'Ë': 1,
#  'Ï': 1,
#  'Ÿ': 1,
#  'ÿ': 1,
#  'Ã': 1,
#  'Ẽ': 1,
#  'ẽ': 2,
#  'Ĩ': 1,
#  'Ñ': 3,
#  'Õ': 4,
#  'Ũ': 1,
#  'ũ': 1,
#  'Ỹ': 1,
#  'ỹ': 2,
#  'Ç': 9,
#  'Ģ': 2,
#  'Ķ': 1,
#  'ķ': 1,
#  'Ļ': 1,
#  'ļ': 1,
#  'Ņ': 1,
#  'ņ': 1,
#  'Ŗ': 1,
#  'ŗ': 1,
#  'Ţ': 1,
#  'Ů': 1,
#  'ů': 5,
#  'Ǎ': 1,
#  'Ď': 2,
#  'ď': 1,
#  'Ě': 1,
#  'Ǐ': 1,
#  'ǐ': 1,
#  'Ľ': 1,
#  'ľ': 1,
#  'Ň': 1,
#  'ň': 2,
#  'Ǒ': 1,
#  'ǒ': 1,
#  'Ř': 1,
#  'Ť': 1,
#  'ť': 1,
#  'Ž': 1,
#  'Ā': 1,
#  'Ē': 1,
#  'Ī': 1,
#  'Ū': 1,
#  'Ȳ': 1,
#  'ȳ': 1,
#  'Ǣ': 1,
#  'ǖ': 1,
#  'ǘ': 1,
#  'ǚ': 1,
#  'ǜ': 1,
#  'Ă': 5,
#  'Ĕ': 1,
#  'ĕ': 1,
#  'Ğ': 1,
#  'Ĭ': 1,
#  'ĭ': 1,
#  'Ŏ': 1,
#  'Ŭ': 1,
#  'Ċ': 2,
#  'ċ': 2,
#  'Ė': 3,
#  'ė': 3,
#  'Ġ': 1,
#  'ġ': 1,
#  'Ż': 1,
#  'Ą': 1,
#  'Ę': 1,
#  'Į': 1,
#  'į': 1,
#  'Ǫ': 1,
#  'ǫ': 1,
#  'Ų': 1,
#  'ų': 1,
#  'Ḥ': 1,
#  'ḥ': 2,
#  'Ḷ': 1,
#  'ḷ': 3,
#  'Ḹ': 1,
#  'ḹ': 1,
#  'Ṃ': 1,
#  'ṃ': 1,
#  'Ṇ': 1,
#  'Ṛ': 1,
#  'ṛ': 7,
#  'Ṝ': 1,
#  'ṝ': 1,
#  'ṣ': 4,
#  'Ṭ': 1,
#  'ṭ': 3,
#  'Ł': 1,
#  'Ő': 6,
#  'Ű': 2,
#  'Ŀ': 1,
#  'ŀ': 1,
#  'Ħ': 1,
#  'ħ': 2,
#  'Þ': 1,
#  'þ': 4,
#  'Œ': 1,
#  'œ': 8,
#  'Æ': 9,
#  'Ə': 1,
#  'Ά': 1,
#  'Έ': 1,
#  'Ή': 1,
#  'Ί': 1,
#  'Ό': 1,
#  'Ύ': 1,
#  'ύ': 4,
#  'Ώ': 1,
#  'Γ': 1,
#  'Ζ': 1,
#  'Θ': 3,
#  'Ο': 4,
#  'Φ': 2,
#  'Ґ': 1,
#  'ґ': 1,
#  'Ѓ': 1,
#  'Ђ': 1,
#  'ђ': 1,
#  'Ё': 1,
#  'Є': 1,
#  'є': 1,
#  'Ж': 1,
#  'Ѕ': 1,
#  'ѕ': 1,
#  'І': 1,
#  'і': 1,
#  'Ї': 1,
#  'ї': 2,
#  'Ј': 1,
#  'Љ': 1,
#  'Њ': 1,
#  'њ': 2,
#  'Т': 6,
#  'Ћ': 1,
#  'ћ': 1,
#  'У': 9,
#  'Ў': 1,
#  'ў': 1,
#  'Ф': 2,
#  'Х': 4,
#  'Џ': 1,
#  'џ': 1,
#  'Щ': 1,
#  'Ъ': 1,
#  'ъ': 5,
#  'Ы': 1,
#  'Ь': 2,
#  'Э': 3,
#  'э': 14,
#  'Ю': 2,
#  'ю': 18,
#  '̪': 4,
#  'ʈ': 1,
#  'ɖ': 1,
#  'ɟ': 1,
#  'ɡ': 6,
#  'ɢ': 1,
#  'ʡ': 1,
#  'ɸ': 1,
#  'ʒ': 1,
#  'ɕ': 2,
#  'ʂ': 1,
#  'ʐ': 1,
#  'ʝ': 1,
#  'ɣ': 1,
#  'ʁ': 1,
#  'ʜ': 1,
#  'ʢ': 1,
#  'ɦ': 5,
#  'ɱ': 2,
#  'ɳ': 1,
#  'ɲ': 2,
#  'ŋ': 2,
#  'ɴ': 1,
#  'ʋ': 1,
#  'ɹ': 1,
#  'ɻ': 1,
#  'ɰ': 1,
#  'ʙ': 1,
#  'ʀ': 1,
#  'ɽ': 1,
#  'ɫ': 1,
#  'ɬ': 1,
#  'ɮ': 1,
#  'ɺ': 1,
#  'ɭ': 1,
#  ...}

# %%
# Transform each comment in the training data to arrays of equal length
train_matrix = tokenizer.texts_to_matrix(train_text)

# %%
# Dimensions of our training matrix
train_matrix.shape[0], train_matrix.shape[1]
# Out:
# (69526, 1558)

# %%
# The list of gold-standard labels for training data
train_labels = train_data["attack"].tolist()

# %%
# Make a model.
model = Sequential()
model.add(Dense(2, input_dim=len(char_unigrams)))
model.add(Dense(1, activation='sigmoid'))

# %%
# Recall from earlier that char unigram vocab size is 728.
# Make the embedding... 
# There's probably something wrong here so fix later.
model.add(Embedding(728, 10, input_length=train_matrix.shape[1]))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# Validate on the training data to start out.
# This doesn't work at the moment.
model.fit(train_matrix, train_labels,
          batch_size=100,
          epochs=2,
          validation_data=(train_matrix, train_labels))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-312895f46c5f> in <module>()
#       2           batch_size=100,
#       3           epochs=2,
# ----> 4           validation_data=(train_matrix, train_labels))
#
# /Users/jangmi/anaconda3/envs/keras-test/lib/python3.6/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     843                               class_weight=class_weight,
#     844                               sample_weight=sample_weight,
# --> 845                               initial_epoch=initial_epoch)
#     846
#     847     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /Users/jangmi/anaconda3/envs/keras-test/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1403             class_weight=class_weight,
#    1404             check_batch_axis=False,
# -> 1405             batch_size=batch_size)
#    1406         # prepare validation data
#    1407         if validation_data:
#
# /Users/jangmi/anaconda3/envs/keras-test/lib/python3.6/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_batch_axis, batch_size)
#    1293                                     self._feed_input_shapes,
#    1294                                     check_batch_axis=False,
# -> 1295                                     exception_prefix='model input')
#    1296         y = _standardize_input_data(y, self._feed_output_names,
#    1297                                     output_shapes,
#
# /Users/jangmi/anaconda3/envs/keras-test/lib/python3.6/site-packages/keras/engine/training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     131                             ' to have shape ' + str(shapes[i]) +
#     132                             ' but got array with shape ' +
# --> 133                             str(array.shape))
#     134     return arrays
#     135
#
# ValueError: Error when checking model input: expected dense_4_input to have shape (None, 69449) but got array with shape (69526, 1558)
